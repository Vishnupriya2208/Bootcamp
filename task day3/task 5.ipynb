# %%
pip install matplotlib pandas seaborn ipywidgets
# Out:
# Requirement already satisfied: matplotlib in c:\users\sures\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: pandas in c:\users\sures\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: seaborn in c:\users\sures\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: ipywidgets in c:\users\sures\anaconda3\lib\site-packages (7.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sures\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sures\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sures\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\sures\anaconda3\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\sures\anaconda3\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sures\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\sures\anaconda3\lib\site-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\sures\anaconda3\lib\site-packages (from ipywidgets) (8.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\sures\anaconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: decorator in c:\users\sures\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sures\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\sures\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\sures\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sures\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\sures\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\sures\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\sures\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\sures\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sures\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sures\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\sures\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\sures\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\sures\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\sures\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.4.1)
# Requirement already satisfied: wcwidth in c:\users\sures\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\sures\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\sures\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\sures\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sures\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\sures\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\sures\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\sures\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sures\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\sures\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\sures\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.32.2)
# Requirement already satisfied: idna>=2.8 in c:\users\sures\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sures\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sures\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sures\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sures\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sures\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sures\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sures\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\sures\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sures\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sures\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\sures\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\sures\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sures\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sures\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sures\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sures\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\sures\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\sures\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sures\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sures\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sures\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2024.6.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sures\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\sures\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in c:\users\sures\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.0)
# Requirement already satisfied: webencodings in c:\users\sures\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sures\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sures\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sures\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.5)
# Requirement already satisfied: pycparser in c:\users\sures\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sures\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.3)
# Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 uri-template-1.3.0 webcolors-24.11.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import ipywidgets as widgets
from ipywidgets import interactive

data = {
    'Country': ['USA', 'Canada', 'Germany', 'Japan', 'India', 'Brazil'],
    'Income': [60000, 50000, 55000, 40000, 3000, 9000],  
    'Life Expectancy': [79, 82, 81, 84, 70, 75],  
    'Year': [2020, 2020, 2020, 2020, 2020, 2020]
}


df = pd.DataFrame(data)


def plot_bubble_chart(selected_year):
    
    filtered_data = df[df['Year'] == selected_year]

    
    plt.figure(figsize=(10, 6))

    
    sns.scatterplot(x='Income', y='Life Expectancy', data=filtered_data,
                    size='Income', sizes=(50, 200), hue='Country', palette='tab10', legend=False)

    
    plt.title(f'Life Expectancy vs Income ({selected_year})', fontsize=16)
    plt.xlabel('Income (USD)', fontsize=12)
    plt.ylabel('Life Expectancy (Years)', fontsize=12)

    
    plt.show()


year_selector = widgets.Dropdown(
    options=[2020, 2021, 2022],  
    value=2020, 
    description='Year:',
)


interactive_plot = interactive(plot_bubble_chart, selected_year=year_selector)
output = interactive_plot.children[-1]
output.layout.height = '400px'
interactive_plot
# Out:
# interactive(children=(Dropdown(description='Year:', options=(2020, 2021, 2022), value=2020), Output(layout=Lay…
